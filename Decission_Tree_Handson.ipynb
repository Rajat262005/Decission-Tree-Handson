# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajat262005/Decission-Tree-Handson/blob/main/Decission_Tree_Handson.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
from sklearn.datasets import load_iris
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier,plot_tree
import matplotlib.pyplot as plt

# %%
#load and explore dataset
iris = load_iris()
X=iris.data
y=iris.target #labels (0,1,2-> setosa,versicolor,verginica)
df = pd.DataFrame(X, columns=iris.feature_names)
df['target'] = y
df.tail(20)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 130                7.4               2.8                6.1               1.9
# 131                7.9               3.8                6.4               2.0
# 132                6.4               2.8                5.6               2.2
# 133                6.3               2.8                5.1               1.5
# 134                6.1               2.6                5.6               1.4
# 135                7.7               3.0                6.1               2.3
# 136                6.3               3.4                5.6               2.4
# 137                6.4               3.1                5.5               1.8
# 138                6.0               3.0                4.8               1.8
# 139                6.9               3.1                5.4               2.1
# 140                6.7               3.1                5.6               2.4
# ...

# %%
#train a decision tree model
clf= DecisionTreeClassifier(
    criterion='entropy',
    max_depth=3, #prevent overfitting
    random_state=42
)
clf.fit(X,y)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=42)

# %%
#visualize Tree
plt.figure(figsize=(10,10))
plot_tree(
    clf,
    feature_names=iris.feature_names,
    class_names=iris.target_names,
    filled=True
)
plt.show()

# %%
#make predictions
sample = [[5.1,3.5,1.4,0.2]]
prediction=clf.predict(sample)
print(f"prediction:{prediction}")
# Out:
# prediction:[0]

# %%
#Evaluate Performance
from sklearn.metrics import accuracy_score
y_pred = clf.predict(X)
print("Training Accuracy:",accuracy_score(y,y_pred))
# Out:
# Training Accuracy: 0.9733333333333334

# %%
#View the decision path for sample
sample_index=0
sample_path = clf.decision_path([X[sample_index]])
print("Decision path for sample (node indices):",sample_path.indices)
# Out:
# Decision path for sample (node indices): [0 1]
